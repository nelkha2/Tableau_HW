# %%
# Dependencies
import pandas as pd

# %%
# Store filepath in a variable
dec_file = "201812-citibike-tripdata.csv/201812-citibike-tripdata.csv"
july_file = "201807-citibike-tripdata.csv/201807-citibike-tripdata.csv"

# %%
#create df's 
dec_file_df = pd.read_csv(dec_file, encoding="ISO-8859-1")
july_file_df = pd.read_csv(july_file, encoding="ISO-8859-1")

# %%
dec_file_df
# Out:
#         year-month  tripduration starttime stoptime  start station id  \
# 0          2018-12           689   00:04.3  11:33.8            3359.0
# 1          2018-12           204   00:05.5  03:30.5            3504.0
# 2          2018-12           316   00:10.2  05:27.2             270.0
# 3          2018-12           726   00:22.0  12:28.2             495.0
# 4          2018-12           397   00:29.6  07:07.4             473.0
# 5          2018-12           299   00:30.9  05:30.6             237.0
# 6          2018-12           414   00:34.7  07:29.3              79.0
# 7          2018-12           216   00:39.9  04:16.7            3147.0
# 8          2018-12         43287   00:49.9  02:17.0             525.0
# 9          2018-12           363   00:57.8  07:01.1            3575.0
# 10         2018-12           807   01:06.1  14:33.5            3658.0
# 11         2018-12           266   00:55.7  05:22.1             358.0
# ...

# %%
july_file_df
# Out:
#         year-month  tripduration starttime stoptime  start station id  \
# 0          2018-07           500   33:51.3  42:12.0                72
# 1          2018-07           455   06:54.0  14:29.1                72
# 2          2018-07          1080   09:16.5  27:17.0                72
# 3          2018-07           632   55:04.6  05:36.8                72
# 4          2018-07          1676   24:27.4  52:23.8                72
# 5          2018-07          1708   26:07.0  54:35.6                72
# 6          2018-07          1582   42:58.0  09:20.3                72
# 7          2018-07          2145   51:58.5  27:44.2                72
# 8          2018-07          1248   12:48.1  33:36.4                72
# 9          2018-07          1578   21:26.6  47:45.6                72
# 10         2018-07          1545   21:47.7  47:33.7                72
# 11         2018-07           265   50:53.1  55:18.8                72
# ...

# %%
df_combined = pd.concat([dec_file_df, july_file_df])
df_combined
# Out:
#         year-month  tripduration starttime stoptime  start station id  \
# 0          2018-12           689   00:04.3  11:33.8            3359.0
# 1          2018-12           204   00:05.5  03:30.5            3504.0
# 2          2018-12           316   00:10.2  05:27.2             270.0
# 3          2018-12           726   00:22.0  12:28.2             495.0
# 4          2018-12           397   00:29.6  07:07.4             473.0
# 5          2018-12           299   00:30.9  05:30.6             237.0
# 6          2018-12           414   00:34.7  07:29.3              79.0
# 7          2018-12           216   00:39.9  04:16.7            3147.0
# 8          2018-12         43287   00:49.9  02:17.0             525.0
# 9          2018-12           363   00:57.8  07:01.1            3575.0
# 10         2018-12           807   01:06.1  14:33.5            3658.0
# 11         2018-12           266   00:55.7  05:22.1             358.0
# ...

# %%
#Export combined df to csv 
df_combined.to_csv(r'C:\Users\Nader\OneDrive\Education\SMU Data Science\Tableau\HW\Dec_and_July_2018.csv')
